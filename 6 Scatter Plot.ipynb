# %% [markdown]
# # Machine Learning - Scatter Plot

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# adalah diagram di mana setiap nilai dalam kumpulan data diwakili oleh sebuah titik.

# %% [markdown]
# Modul Matplotlib memiliki metode untuk menggambar scatter plot, dibutuhkan dua larik dengan panjang yang sama, satu untuk nilai sumbu x, dan satu lagi untuk nilai sumbu y:
#
# ```
# x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
#
# y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
# ```
#
# Array x mewakili usia setiap mobil.
#
# Array y mewakili kecepatan setiap mobil.

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Sumbu x mewakili usia, dan sumbu y mewakili kecepatan.
#
# Yang dapat kita baca dari diagram tersebut adalah bahwa dua mobil tercepat sama-sama berumur 2 tahun, dan mobil paling lambat berumur 12 tahun.

# %% [markdown]
# ### Random Data Distributions

# %% [markdown]
# Dalam Pembelajaran Mesin, kumpulan data dapat berisi ribuan, atau bahkan jutaan, nilai.
#
# Anda mungkin tidak memiliki data dunia nyata saat menguji algoritme, Anda mungkin harus menggunakan nilai yang dihasilkan secara acak.
#
# Seperti yang telah kita pelajari di bab sebelumnya, modul NumPy dapat membantu kita dalam hal itu!
#
# Mari kita buat dua larik yang keduanya diisi dengan 1000 angka acak dari distribusi data normal.
#
# Larik pertama akan memiliki rata-rata yang disetel ke 5,0 dengan standar deviasi 1,0.
#
# Larik kedua akan memiliki rata-rata yang disetel ke 10,0 dengan standar deviasi 2,0:

# %%
# A scatter plot with 1000 dots:

import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Kita dapat melihat bahwa titik-titik terkonsentrasi di sekitar nilai 5 pada sumbu x, dan 10 pada sumbu y.
#
# Kita juga dapat melihat bahwa sebaran lebih lebar pada sumbu y daripada pada sumbu x.
