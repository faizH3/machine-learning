# %% [markdown]
# # Machine Learning - Polynomial Regression

# %% [markdown]
# ### Polynomial Regression

# %% [markdown]
# Jika titik data Anda jelas tidak sesuai dengan regresi linier (garis lurus melalui semua titik data), ini mungkin ideal untuk regresi polinomial.
#
# Regresi polinomial, seperti regresi linier, menggunakan hubungan antara variabel x dan y untuk menemukan cara terbaik menggambar garis melalui titik data.

# %% [markdown]
# Python memiliki metode untuk menemukan hubungan antara titik data dan menggambar garis regresi polinomial.
#
# Pada contoh di bawah ini, kami telah mendaftarkan 18 mobil saat melewati gardu tol tertentu.
#
# Kami telah mendaftarkan kecepatan mobil, dan waktu hari (jam) terjadinya lewat.
#
# Sumbu x mewakili jam dalam sehari dan sumbu y mewakili kecepatan:

# %%
import numpy
import matplotlib.pyplot as plt
# jam/hari
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
print(len(x))

# kecepatan
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
print(len(y))
mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()
# Out:
# 18
# 18

# %% [markdown]
# ### 2 R-Squared

# %% [markdown]
# Penting untuk mengetahui seberapa baik hubungan antara nilai sumbu x dan sumbu y, jika tidak ada hubungan maka regresi polinomial tidak dapat digunakan untuk memprediksi apapun.
#
# Hubungan diukur dengan nilai yang disebut r-kuadrat.
#
# Nilai r-kuadrat berkisar antara 0 sampai 1, dimana 0 berarti tidak ada hubungan, dan 1 berarti 100% berhubungan.

# %%
# Seberapa cocok data saya dalam regresi polinomial?

import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451026

# %% [markdown]
# ### 3 Predict Future Values

# %% [markdown]
# Sekarang kita dapat menggunakan informasi yang telah kita kumpulkan untuk memprediksi nilai masa depan.
#
# Contoh: Mari kita coba memprediksi kecepatan mobil yang melewati pintu tol sekitar pukul 17:00:
#
# Untuk melakukannya, kita membutuhkan mymodelarray yang sama dari contoh di atas:

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)
print(speed)
# Out:
# 88.87331269698007

# %%
import numpy
import matplotlib.pyplot as plt
# jam/hari
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
print(len(x))

# kecepatan
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
print(len(y))
mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)


myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)

# coordinat (17, 88.87331269698007)
plt.scatter(17, speed)

plt.plot(myline, mymodel(myline))
plt.show()
# Out:
# 18
# 18
